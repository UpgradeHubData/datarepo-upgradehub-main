# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Para estos mismos datos, emplead las implementaciones de Adaboost, LightGBM y CatBoost.

# %% [markdown]
# ## Con Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.datasets import make_classification
from sklearn.preprocessing import OneHotEncoder
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import roc_curve,auc, confusion_matrix, classification_report

# %%
# Volvemos a cargar los datos sobre el accidente del titanic, uno de los datasets más utilizados en problemas de clasificación
df_train = pd.read_csv('//content/drive/MyDrive/Colab Notebooks/Apuntes/semana_8/modelos_supervisados/train_titanic.csv')

# %%
# Algo importante a la hora de trabajar con este set de datos y con cualquier otro es mirar si tiene 
# variables categóricas (no numéricas) porque necesitamos transformarlas a numéricas para poder proporcionárselo al modelo
df_train['Embarked'].fillna(value='S',inplace=True)
df_train['Fare'].fillna(value=df_train['Fare'].mean(),inplace=True)
df_train['Age'].fillna(value=df_train['Age'].mean(),inplace=True)

# %%
sex_categories = {'female':0,'male':1}
# Vamos a utilizar la función map para transformar las variable del sexo del pasajero a numérica
df_train['Sex'] = df_train['Sex'].map(sex_categories)

# %%
# Para el puerto de embarque,vamos a utilzar una técnica que se llama one-hot encoding
one_hot_encoding_train = pd.get_dummies(df_train['Embarked'])
df_train = pd.concat([df_train, one_hot_encoding_train], axis=1)
df_train= df_train.drop(['Embarked'],axis=1)

# %%
# Vamos a eliminar las columnas que no nos interesan
df_train = df_train.drop(['Name', 'Cabin', 'Ticket', 'Fare', 'PassengerId'], axis=1)

# %%
# Antes de crear el modelo hacemos la separación del set de entrenamiento y el set de pruebas
X_train, X_test, y_train, y_test = train_test_split(df_train.loc[:, df_train.columns != 'Survived'], df_train['Survived'], test_size=0.2, stratify=df_train['Survived'],random_state=123)

# %%
# vamos a crear nuestra instancia del modelo
adab = AdaBoostClassifier()

# %%
# Entrenamos el modelo con el set de datos de entrenamiento
adab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
# Podemos generar predicciones para el set de pruebas
y_predict = adab.predict(X_test)

# %%
# ahora vamos a ver qué tal lo ha hecho el modelo AdaBoost
pred_proba = adab.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, pred_proba[:, 1])
roc_auc = auc(fpr, tpr)

roc_auc
# Out:
# 0.8388010540184453

# %%
# vamos a pintar la curva del ROC / AUC
plt.plot(fpr,tpr)
plt.plot([0, 1], [0, 1], color='r', lw=2, linestyle='--')
plt.xlabel('1 - Exhaustividad (recall) ')
plt.ylabel('Precision')
plt.title('Receiver Operator Characteristic')
plt.show()

# %%
# Otras métrica que podemos sacar son la matriz de confusión del modelo
print(confusion_matrix(y_test, y_predict))
# Out:
# [[98 12]
#  [23 46]]

# %%
# Scikit-learn también nos permite calcular fácilmente otras métricas como el F1-score, 
# la precisión del modelo y el recall
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       110
#            1       0.79      0.67      0.72        69
#
#     accuracy                           0.80       179
#    macro avg       0.80      0.78      0.79       179
# weighted avg       0.80      0.80      0.80       179

# %%
features = X_train
feature_list = X_train.columns

# Guardamos los valores numéricos de la importancia de cada feature
importances = list(adab.feature_importances_)

# Vamos a crear un lista de tuplas con la variable independiente de entrada y su importancia
feature_importances = [(feature, round(importance, 4)) for feature, importance in zip(feature_list, importances)]

# Ordenamos las importancias de las variables para tener las más importantes al principio
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Mostramos las variables y sus importancias
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: Age                  Importance: 0.7
# Variable: Pclass               Importance: 0.1
# Variable: SibSp                Importance: 0.08
# Variable: Parch                Importance: 0.06
# Variable: Sex                  Importance: 0.04
# Variable: S                    Importance: 0.02
# Variable: C                    Importance: 0.0
# Variable: Q                    Importance: 0.0

# %%
# También podemos tener una representación gráfica
# creamos una lista con tantas variables como vayamos a pintar
x_values = list(range(len(importances)))

# Creamos un gráfico de barras
plt.bar(x_values, importances, orientation = 'vertical')

# Ponemos los nombres de las variables en el eje x
plt.xticks(x_values, feature_list, rotation='vertical')

# Axis labels and title
# Ponemos los nombres de los ejes y el título
plt.ylabel('Importancia'); plt.xlabel('Variable'); plt.title('Importancias de las variables de entrada');

# %% [markdown]
# ## Con LightGBM

# %%
import lightgbm as lgb
from sklearn.preprocessing import OneHotEncoder
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import roc_curve,auc, confusion_matrix, classification_report

# %%
# Volvemos a cargar los datos sobre el accidente del titanic, uno de los datasets más utilizados en problemas de clasificación
df_train = pd.read_csv('//content/drive/MyDrive/Colab Notebooks/Apuntes/semana_8/modelos_supervisados/train_titanic.csv')

# %%
# Algo importante a la hora de trabajar con este set de datos y con cualquier otro es mirar si tiene 
# variables categóricas (no numéricas) porque necesitamos transformarlas a numéricas para poder proporcionárselo al modelo
df_train['Embarked'].fillna(value='S',inplace=True)
# df_train['Fare'].fillna(value=df_train['Fare'].mean(),inplace=True)
df_train['Age'].fillna(value=df_train['Age'].mean(),inplace=True)

# %%
sex_categories = {'female':0,'male':1}
# Vamos a utilizar la función map para transformar las variable del sexo del pasajero a numérica
df_train['Sex'] = df_train['Sex'].map(sex_categories)

# %%
# Para el puerto de embarque,vamos a utilzar una técnica que se llama one-hot encoding
one_hot_encoding_train = pd.get_dummies(df_train['Embarked'])
df_train = pd.concat([df_train, one_hot_encoding_train], axis=1)
df_train= df_train.drop(['Embarked'],axis=1)

# %%
# Vamos a eliminar las columnas que no nos interesan
df_train = df_train.drop(['Name', 'Cabin', 'Ticket', 'Fare', 'PassengerId'], axis=1)

# %%
# Antes de crear el modelo hacemos la separación del set de entrenamiento y el set de pruebas
X_train, X_test, y_train, y_test = train_test_split(df_train.loc[:, df_train.columns != 'Survived'], df_train['Survived'], test_size=0.2, stratify=df_train['Survived'],random_state=123)

# %%
# vamos a crear nuestra instancia del modelo
clf = lgb.LGBMClassifier()

# %%
# Entrenamos el modelo con el set de datos de entrenamiento
clf.fit(X_train, y_train)
# Out:
# LGBMClassifier()

# %%
# Podemos generar predicciones para el set de pruebas
y_predict = clf.predict(X_test)

# %%
# ahora vamos a ver qué tal lo ha hecho el modelo lightgbm
pred_proba = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, pred_proba[:, 1])
roc_auc = auc(fpr, tpr)

roc_auc
# Out:
# 0.8449275362318841

# %%
# vamos a pintar la curva del ROC / AUC
plt.plot(fpr,tpr)
plt.plot([0, 1], [0, 1], color='r', lw=2, linestyle='--')
plt.xlabel('1 - Exhaustividad (recall) ')
plt.ylabel('Precision')
plt.title('Receiver Operator Characteristic')
plt.show()

# %%
# Otras métrica que podemos sacar son la matriz de confusión del modelo
print(confusion_matrix(y_test, y_predict))
# Out:
# [[93 17]
#  [19 50]]

# %%
# Scikit-learn también nos permite calcular fácilmente otras métricas como el F1-score, 
# la precisión del modelo y el recall
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       110
#            1       0.75      0.72      0.74        69
#
#     accuracy                           0.80       179
#    macro avg       0.79      0.79      0.79       179
# weighted avg       0.80      0.80      0.80       179

# %% [markdown]
# ## Con CatBoost

# %%
! pip install catboost

# %%
from catboost import CatBoostClassifier
from sklearn.datasets import make_classification
from sklearn.preprocessing import OneHotEncoder
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import roc_curve,auc, confusion_matrix, classification_report

# %%
# Volvemos a cargar los datos sobre el accidente del titanic, uno de los datasets más utilizados en problemas de clasificación
df_train = pd.read_csv('//content/drive/MyDrive/Colab Notebooks/Apuntes/semana_8/modelos_supervisados/train_titanic.csv')

# %%
# Algo importante a la hora de trabajar con este set de datos y con cualquier otro es mirar si tiene 
# variables categóricas (no numéricas) porque necesitamos transformarlas a numéricas para poder proporcionárselo al modelo
df_train['Embarked'].fillna(value='S',inplace=True)
# df_train['Fare'].fillna(value=df_train['Fare'].mean(),inplace=True)
df_train['Age'].fillna(value=df_train['Age'].mean(),inplace=True)

# %%
sex_categories = {'female':0,'male':1}
# Vamos a utilizar la función map para transformar las variable del sexo del pasajero a numérica
df_train['Sex'] = df_train['Sex'].map(sex_categories)

# %%
# Para el puerto de embarque,vamos a utilzar una técnica que se llama one-hot encoding
one_hot_encoding_train = pd.get_dummies(df_train['Embarked'])
df_train = pd.concat([df_train, one_hot_encoding_train], axis=1)
df_train= df_train.drop(['Embarked'],axis=1)

# %%
# Vamos a eliminar las columnas que no nos interesan
df_train = df_train.drop(['Name', 'Cabin', 'Ticket', 'Fare', 'PassengerId'], axis=1)

# %%
# Antes de crear el modelo hacemos la separación del set de entrenamiento y el set de pruebas
X_train, X_test, y_train, y_test = train_test_split(df_train.loc[:, df_train.columns != 'Survived'], df_train['Survived'], test_size=0.2, stratify=df_train['Survived'],random_state=123)

# %%
# vamos a crear nuestra instancia del modelo
clf = CatBoostClassifier()
# clf = CatBoostClassifier(iterations=25, learning_rate=0.1)

# %%
# Entrenamos el modelo con el set de datos de entrenamiento
clf.fit(X_train, y_train)
# Out:
# Learning rate set to 0.008911
# 0:	learn: 0.6873886	total: 959us	remaining: 959ms
# 1:	learn: 0.6828062	total: 9.12ms	remaining: 4.55s
# 2:	learn: 0.6775244	total: 12.4ms	remaining: 4.11s
# 3:	learn: 0.6727070	total: 17.1ms	remaining: 4.26s
# 4:	learn: 0.6678993	total: 19.9ms	remaining: 3.95s
# 5:	learn: 0.6633467	total: 20.6ms	remaining: 3.41s
# 6:	learn: 0.6577985	total: 21.3ms	remaining: 3.02s
# 7:	learn: 0.6527433	total: 23ms	remaining: 2.85s
# 8:	learn: 0.6477615	total: 24.5ms	remaining: 2.69s
# 9:	learn: 0.6425960	total: 26.7ms	remaining: 2.64s
# 10:	learn: 0.6375041	total: 28.2ms	remaining: 2.53s
# 11:	learn: 0.6334308	total: 30ms	remaining: 2.47s
# 12:	learn: 0.6285795	total: 31.3ms	remaining: 2.37s
# 13:	learn: 0.6240329	total: 32.8ms	remaining: 2.31s
# 14:	learn: 0.6197275	total: 34.2ms	remaining: 2.25s
# 15:	learn: 0.6152702	total: 35.6ms	remaining: 2.19s
# 16:	learn: 0.6101574	total: 37.1ms	remaining: 2.14s
# 17:	learn: 0.6055444	total: 38.5ms	remaining: 2.1s
# 18:	learn: 0.6015443	total: 39.8ms	remaining: 2.06s
# 19:	learn: 0.5975836	total: 41.2ms	remaining: 2.02s
# 20:	learn: 0.5940518	total: 42.5ms	remaining: 1.98s
# 21:	learn: 0.5907000	total: 43.8ms	remaining: 1.95s
# 22:	learn: 0.5874245	total: 45.1ms	remaining: 1.92s
# 23:	learn: 0.5838158	total: 46.3ms	remaining: 1.88s
# 24:	learn: 0.5804760	total: 47.6ms	remaining: 1.85s
# 25:	learn: 0.5776726	total: 49ms	remaining: 1.83s
# 26:	learn: 0.5743576	total: 50.3ms	remaining: 1.81s
# 27:	learn: 0.5708272	total: 51.6ms	remaining: 1.79s
# 28:	learn: 0.5673307	total: 52.9ms	remaining: 1.77s
# 29:	learn: 0.5647562	total: 54.1ms	remaining: 1.75s
# 30:	learn: 0.5623016	total: 54.7ms	remaining: 1.71s
# 31:	learn: 0.5593020	total: 59.5ms	remaining: 1.8s
# 32:	learn: 0.5562237	total: 63.6ms	remaining: 1.86s
# 33:	learn: 0.5527119	total: 68ms	remaining: 1.93s
# 34:	learn: 0.5496047	total: 72.2ms	remaining: 1.99s
# 35:	learn: 0.5468928	total: 76.4ms	remaining: 2.05s
# 36:	learn: 0.5446542	total: 77.8ms	remaining: 2.02s
# 37:	learn: 0.5417290	total: 81.2ms	remaining: 2.06s
# 38:	learn: 0.5398393	total: 85.8ms	remaining: 2.11s
# 39:	learn: 0.5381357	total: 88.2ms	remaining: 2.12s
# 40:	learn: 0.5363158	total: 89.5ms	remaining: 2.09s
# 41:	learn: 0.5330389	total: 90.8ms	remaining: 2.07s
# 42:	learn: 0.5302256	total: 92.8ms	remaining: 2.07s
# 43:	learn: 0.5280424	total: 93.7ms	remaining: 2.04s
# 44:	learn: 0.5252016	total: 94.8ms	remaining: 2.01s
# 45:	learn: 0.5224371	total: 96ms	remaining: 1.99s
# 46:	learn: 0.5206973	total: 97.1ms	remaining: 1.97s
# 47:	learn: 0.5188474	total: 98.2ms	remaining: 1.95s
# 48:	learn: 0.5163054	total: 99.6ms	remaining: 1.93s
# 49:	learn: 0.5140019	total: 101ms	remaining: 1.92s
# 50:	learn: 0.5117833	total: 102ms	remaining: 1.9s
# 51:	learn: 0.5098753	total: 104ms	remaining: 1.89s
# 52:	learn: 0.5077050	total: 105ms	remaining: 1.88s
# 53:	learn: 0.5055371	total: 106ms	remaining: 1.86s
# 54:	learn: 0.5033354	total: 111ms	remaining: 1.91s
# 55:	learn: 0.5011404	total: 112ms	remaining: 1.9s
# 56:	learn: 0.4990260	total: 114ms	remaining: 1.88s
# 57:	learn: 0.4970101	total: 115ms	remaining: 1.87s
# 58:	learn: 0.4951251	total: 117ms	remaining: 1.86s
# 59:	learn: 0.4937346	total: 118ms	remaining: 1.84s
# 60:	learn: 0.4919811	total: 119ms	remaining: 1.83s
# 61:	learn: 0.4901502	total: 120ms	remaining: 1.82s
# 62:	learn: 0.4879980	total: 122ms	remaining: 1.81s
# 63:	learn: 0.4871530	total: 123ms	remaining: 1.8s
# 64:	learn: 0.4849230	total: 124ms	remaining: 1.78s
# 65:	learn: 0.4832286	total: 125ms	remaining: 1.77s
# 66:	learn: 0.4813670	total: 127ms	remaining: 1.76s
# 67:	learn: 0.4798173	total: 128ms	remaining: 1.76s
# 68:	learn: 0.4784309	total: 130ms	remaining: 1.75s
# 69:	learn: 0.4766375	total: 131ms	remaining: 1.74s
# 70:	learn: 0.4751942	total: 133ms	remaining: 1.74s
# 71:	learn: 0.4742449	total: 134ms	remaining: 1.73s
# 72:	learn: 0.4726276	total: 136ms	remaining: 1.72s
# 73:	learn: 0.4714781	total: 137ms	remaining: 1.71s
# 74:	learn: 0.4701169	total: 138ms	remaining: 1.71s
# 75:	learn: 0.4687672	total: 140ms	remaining: 1.7s
# 76:	learn: 0.4674483	total: 141ms	remaining: 1.69s
# 77:	learn: 0.4662884	total: 142ms	remaining: 1.68s
# 78:	learn: 0.4648330	total: 144ms	remaining: 1.68s
# 79:	learn: 0.4632689	total: 145ms	remaining: 1.67s
# 80:	learn: 0.4616349	total: 147ms	remaining: 1.67s
# 81:	learn: 0.4601272	total: 149ms	remaining: 1.67s
# 82:	learn: 0.4591340	total: 150ms	remaining: 1.66s
# 83:	learn: 0.4581736	total: 151ms	remaining: 1.65s
# 84:	learn: 0.4565990	total: 152ms	remaining: 1.64s
# 85:	learn: 0.4556718	total: 154ms	remaining: 1.63s
# 86:	learn: 0.4548759	total: 156ms	remaining: 1.63s
# 87:	learn: 0.4536712	total: 157ms	remaining: 1.62s
# 88:	learn: 0.4526883	total: 158ms	remaining: 1.62s
# 89:	learn: 0.4517311	total: 160ms	remaining: 1.61s
# 90:	learn: 0.4507364	total: 161ms	remaining: 1.61s
# 91:	learn: 0.4493917	total: 162ms	remaining: 1.6s
# 92:	learn: 0.4485201	total: 164ms	remaining: 1.6s
# 93:	learn: 0.4473902	total: 165ms	remaining: 1.59s
# 94:	learn: 0.4465498	total: 166ms	remaining: 1.58s
# 95:	learn: 0.4456236	total: 168ms	remaining: 1.58s
# 96:	learn: 0.4445843	total: 169ms	remaining: 1.57s
# 97:	learn: 0.4439223	total: 170ms	remaining: 1.56s
# 98:	learn: 0.4431374	total: 171ms	remaining: 1.56s
# 99:	learn: 0.4423520	total: 173ms	remaining: 1.55s
# 100:	learn: 0.4412896	total: 174ms	remaining: 1.55s
# 101:	learn: 0.4406032	total: 175ms	remaining: 1.54s
# 102:	learn: 0.4395178	total: 177ms	remaining: 1.54s
# 103:	learn: 0.4391123	total: 178ms	remaining: 1.53s
# 104:	learn: 0.4381963	total: 179ms	remaining: 1.52s
# 105:	learn: 0.4370003	total: 181ms	remaining: 1.52s
# 106:	learn: 0.4362149	total: 182ms	remaining: 1.52s
# 107:	learn: 0.4350997	total: 184ms	remaining: 1.52s
# 108:	learn: 0.4343287	total: 185ms	remaining: 1.51s
# 109:	learn: 0.4338840	total: 187ms	remaining: 1.51s
# 110:	learn: 0.4330389	total: 188ms	remaining: 1.5s
# 111:	learn: 0.4321800	total: 189ms	remaining: 1.5s
# 112:	learn: 0.4312931	total: 191ms	remaining: 1.5s
# 113:	learn: 0.4309096	total: 192ms	remaining: 1.49s
# 114:	learn: 0.4300734	total: 193ms	remaining: 1.49s
# 115:	learn: 0.4294485	total: 194ms	remaining: 1.48s
# 116:	learn: 0.4289717	total: 196ms	remaining: 1.48s
# 117:	learn: 0.4282534	total: 197ms	remaining: 1.47s
# 118:	learn: 0.4275047	total: 198ms	remaining: 1.47s
# 119:	learn: 0.4272422	total: 199ms	remaining: 1.46s
# 120:	learn: 0.4266496	total: 200ms	remaining: 1.45s
# 121:	learn: 0.4262243	total: 201ms	remaining: 1.45s
# 122:	learn: 0.4256666	total: 202ms	remaining: 1.44s
# 123:	learn: 0.4252308	total: 203ms	remaining: 1.43s
# 124:	learn: 0.4244740	total: 203ms	remaining: 1.42s
# 125:	learn: 0.4237777	total: 204ms	remaining: 1.42s
# 126:	learn: 0.4231931	total: 205ms	remaining: 1.41s
# 127:	learn: 0.4224277	total: 205ms	remaining: 1.4s
# 128:	learn: 0.4218174	total: 206ms	remaining: 1.39s
# 129:	learn: 0.4211952	total: 206ms	remaining: 1.38s
# 130:	learn: 0.4211107	total: 207ms	remaining: 1.37s
# 131:	learn: 0.4205189	total: 207ms	remaining: 1.36s
# 132:	learn: 0.4201217	total: 208ms	remaining: 1.35s
# 133:	learn: 0.4194704	total: 208ms	remaining: 1.35s
# 134:	learn: 0.4188641	total: 209ms	remaining: 1.34s
# 135:	learn: 0.4182444	total: 210ms	remaining: 1.33s
# 136:	learn: 0.4176404	total: 210ms	remaining: 1.32s
# 137:	learn: 0.4172683	total: 211ms	remaining: 1.31s
# 138:	learn: 0.4165419	total: 211ms	remaining: 1.31s
# 139:	learn: 0.4160931	total: 212ms	remaining: 1.3s
# 140:	learn: 0.4156690	total: 212ms	remaining: 1.29s
# 141:	learn: 0.4149428	total: 213ms	remaining: 1.29s
# 142:	learn: 0.4143641	total: 214ms	remaining: 1.28s
# 143:	learn: 0.4139625	total: 214ms	remaining: 1.27s
# 144:	learn: 0.4136673	total: 215ms	remaining: 1.26s
# 145:	learn: 0.4131393	total: 215ms	remaining: 1.26s
# 146:	learn: 0.4126255	total: 216ms	remaining: 1.25s
# 147:	learn: 0.4123479	total: 216ms	remaining: 1.25s
# 148:	learn: 0.4119763	total: 217ms	remaining: 1.24s
# 149:	learn: 0.4118136	total: 217ms	remaining: 1.23s
# 150:	learn: 0.4115190	total: 218ms	remaining: 1.23s
# 151:	learn: 0.4109611	total: 219ms	remaining: 1.22s
# 152:	learn: 0.4108708	total: 219ms	remaining: 1.21s
# 153:	learn: 0.4105134	total: 219ms	remaining: 1.21s
# 154:	learn: 0.4100574	total: 220ms	remaining: 1.2s
# 155:	learn: 0.4096706	total: 221ms	remaining: 1.19s
# 156:	learn: 0.4092066	total: 221ms	remaining: 1.19s
# 157:	learn: 0.4084693	total: 222ms	remaining: 1.18s
# 158:	learn: 0.4081858	total: 222ms	remaining: 1.18s
# 159:	learn: 0.4075971	total: 223ms	remaining: 1.17s
# 160:	learn: 0.4069444	total: 223ms	remaining: 1.16s
# 161:	learn: 0.4064277	total: 224ms	remaining: 1.16s
# 162:	learn: 0.4063130	total: 225ms	remaining: 1.15s
# 163:	learn: 0.4060135	total: 225ms	remaining: 1.15s
# 164:	learn: 0.4054235	total: 226ms	remaining: 1.14s
# 165:	learn: 0.4051348	total: 226ms	remaining: 1.14s
# 166:	learn: 0.4047059	total: 227ms	remaining: 1.13s
# 167:	learn: 0.4042887	total: 227ms	remaining: 1.13s
# 168:	learn: 0.4039368	total: 228ms	remaining: 1.12s
# 169:	learn: 0.4036339	total: 229ms	remaining: 1.11s
# 170:	learn: 0.4032460	total: 229ms	remaining: 1.11s
# 171:	learn: 0.4028215	total: 230ms	remaining: 1.11s
# 172:	learn: 0.4023612	total: 230ms	remaining: 1.1s
# 173:	learn: 0.4019591	total: 231ms	remaining: 1.1s
# 174:	learn: 0.4017584	total: 232ms	remaining: 1.09s
# 175:	learn: 0.4014341	total: 233ms	remaining: 1.09s
# 176:	learn: 0.4010894	total: 234ms	remaining: 1.09s
# 177:	learn: 0.4006774	total: 234ms	remaining: 1.08s
# 178:	learn: 0.4004831	total: 235ms	remaining: 1.08s
# 179:	learn: 0.3999311	total: 236ms	remaining: 1.07s
# 180:	learn: 0.3994461	total: 236ms	remaining: 1.07s
# 181:	learn: 0.3991925	total: 237ms	remaining: 1.06s
# 182:	learn: 0.3990066	total: 238ms	remaining: 1.06s
# 183:	learn: 0.3985585	total: 238ms	remaining: 1.06s
# 184:	learn: 0.3983995	total: 239ms	remaining: 1.05s
# 185:	learn: 0.3983421	total: 239ms	remaining: 1.05s
# 186:	learn: 0.3977299	total: 240ms	remaining: 1.04s
# 187:	learn: 0.3974098	total: 240ms	remaining: 1.04s
# 188:	learn: 0.3970747	total: 241ms	remaining: 1.03s
# 189:	learn: 0.3966383	total: 242ms	remaining: 1.03s
# 190:	learn: 0.3965034	total: 242ms	remaining: 1.03s
# 191:	learn: 0.3962727	total: 243ms	remaining: 1.02s
# 192:	learn: 0.3958752	total: 243ms	remaining: 1.02s
# 193:	learn: 0.3954662	total: 244ms	remaining: 1.01s
# 194:	learn: 0.3953784	total: 244ms	remaining: 1.01s
# 195:	learn: 0.3952050	total: 245ms	remaining: 1s
# 196:	learn: 0.3951173	total: 245ms	remaining: 1s
# 197:	learn: 0.3950135	total: 246ms	remaining: 995ms
# 198:	learn: 0.3948431	total: 246ms	remaining: 991ms
# 199:	learn: 0.3946543	total: 247ms	remaining: 987ms
# 200:	learn: 0.3943044	total: 247ms	remaining: 984ms
# 201:	learn: 0.3942036	total: 248ms	remaining: 979ms
# 202:	learn: 0.3937684	total: 248ms	remaining: 975ms
# 203:	learn: 0.3936918	total: 249ms	remaining: 970ms
# 204:	learn: 0.3934530	total: 249ms	remaining: 967ms
# 205:	learn: 0.3931844	total: 250ms	remaining: 964ms
# 206:	learn: 0.3929487	total: 251ms	remaining: 960ms
# 207:	learn: 0.3926635	total: 251ms	remaining: 957ms
# 208:	learn: 0.3926018	total: 252ms	remaining: 953ms
# 209:	learn: 0.3922615	total: 252ms	remaining: 949ms
# 210:	learn: 0.3919506	total: 253ms	remaining: 946ms
# 211:	learn: 0.3916911	total: 254ms	remaining: 943ms
# 212:	learn: 0.3915554	total: 254ms	remaining: 940ms
# 213:	learn: 0.3910786	total: 255ms	remaining: 936ms
# 214:	learn: 0.3908271	total: 255ms	remaining: 933ms
# 215:	learn: 0.3905066	total: 256ms	remaining: 929ms
# 216:	learn: 0.3902300	total: 257ms	remaining: 926ms
# 217:	learn: 0.3899815	total: 257ms	remaining: 923ms
# 218:	learn: 0.3897640	total: 258ms	remaining: 919ms
# 219:	learn: 0.3894862	total: 258ms	remaining: 916ms
# 220:	learn: 0.3893461	total: 259ms	remaining: 913ms
# 221:	learn: 0.3892982	total: 259ms	remaining: 908ms
# 222:	learn: 0.3891509	total: 260ms	remaining: 905ms
# 223:	learn: 0.3888251	total: 260ms	remaining: 902ms
# 224:	learn: 0.3885360	total: 261ms	remaining: 899ms
# 225:	learn: 0.3884160	total: 262ms	remaining: 896ms
# 226:	learn: 0.3880641	total: 262ms	remaining: 893ms
# 227:	learn: 0.3878345	total: 263ms	remaining: 890ms
# 228:	learn: 0.3875914	total: 263ms	remaining: 886ms
# 229:	learn: 0.3874873	total: 264ms	remaining: 883ms
# 230:	learn: 0.3871397	total: 264ms	remaining: 880ms
# 231:	learn: 0.3869134	total: 265ms	remaining: 876ms
# 232:	learn: 0.3867832	total: 265ms	remaining: 873ms
# 233:	learn: 0.3863699	total: 266ms	remaining: 870ms
# 234:	learn: 0.3861247	total: 266ms	remaining: 867ms
# 235:	learn: 0.3859707	total: 267ms	remaining: 864ms
# 236:	learn: 0.3856916	total: 268ms	remaining: 862ms
# 237:	learn: 0.3853890	total: 268ms	remaining: 859ms
# 238:	learn: 0.3851834	total: 269ms	remaining: 856ms
# 239:	learn: 0.3850409	total: 269ms	remaining: 853ms
# 240:	learn: 0.3848778	total: 270ms	remaining: 851ms
# 241:	learn: 0.3846853	total: 271ms	remaining: 848ms
# 242:	learn: 0.3844438	total: 271ms	remaining: 846ms
# 243:	learn: 0.3842384	total: 272ms	remaining: 843ms
# 244:	learn: 0.3838411	total: 273ms	remaining: 840ms
# 245:	learn: 0.3836024	total: 273ms	remaining: 837ms
# 246:	learn: 0.3833857	total: 274ms	remaining: 835ms
# 247:	learn: 0.3831395	total: 274ms	remaining: 832ms
# 248:	learn: 0.3830859	total: 275ms	remaining: 829ms
# 249:	learn: 0.3829372	total: 275ms	remaining: 826ms
# 250:	learn: 0.3827742	total: 276ms	remaining: 823ms
# 251:	learn: 0.3825783	total: 276ms	remaining: 821ms
# 252:	learn: 0.3825188	total: 277ms	remaining: 818ms
# 253:	learn: 0.3822376	total: 277ms	remaining: 815ms
# 254:	learn: 0.3820162	total: 278ms	remaining: 812ms
# 255:	learn: 0.3819515	total: 279ms	remaining: 810ms
# 256:	learn: 0.3819362	total: 279ms	remaining: 806ms
# 257:	learn: 0.3817707	total: 280ms	remaining: 804ms
# 258:	learn: 0.3816470	total: 280ms	remaining: 801ms
# 259:	learn: 0.3813851	total: 281ms	remaining: 799ms
# 260:	learn: 0.3810434	total: 281ms	remaining: 796ms
# 261:	learn: 0.3808846	total: 282ms	remaining: 794ms
# 262:	learn: 0.3807683	total: 282ms	remaining: 791ms
# 263:	learn: 0.3805762	total: 283ms	remaining: 789ms
# 264:	learn: 0.3804599	total: 283ms	remaining: 786ms
# 265:	learn: 0.3802190	total: 284ms	remaining: 784ms
# 266:	learn: 0.3801075	total: 285ms	remaining: 781ms
# 267:	learn: 0.3798955	total: 285ms	remaining: 779ms
# 268:	learn: 0.3797242	total: 286ms	remaining: 776ms
# 269:	learn: 0.3794624	total: 286ms	remaining: 774ms
# 270:	learn: 0.3793856	total: 287ms	remaining: 772ms
# 271:	learn: 0.3792326	total: 287ms	remaining: 769ms
# 272:	learn: 0.3791108	total: 288ms	remaining: 767ms
# 273:	learn: 0.3788056	total: 288ms	remaining: 764ms
# 274:	learn: 0.3787324	total: 289ms	remaining: 762ms
# 275:	learn: 0.3785908	total: 289ms	remaining: 759ms
# 276:	learn: 0.3784037	total: 290ms	remaining: 757ms
# 277:	learn: 0.3782815	total: 291ms	remaining: 754ms
# 278:	learn: 0.3781620	total: 291ms	remaining: 752ms
# 279:	learn: 0.3780085	total: 292ms	remaining: 750ms
# 280:	learn: 0.3778550	total: 292ms	remaining: 748ms
# 281:	learn: 0.3777527	total: 293ms	remaining: 746ms
# 282:	learn: 0.3775303	total: 294ms	remaining: 744ms
# 283:	learn: 0.3773439	total: 294ms	remaining: 742ms
# 284:	learn: 0.3772994	total: 295ms	remaining: 740ms
# 285:	learn: 0.3771515	total: 295ms	remaining: 738ms
# 286:	learn: 0.3769870	total: 296ms	remaining: 735ms
# 287:	learn: 0.3767524	total: 297ms	remaining: 733ms
# 288:	learn: 0.3766399	total: 297ms	remaining: 731ms
# 289:	learn: 0.3764617	total: 298ms	remaining: 729ms
# 290:	learn: 0.3763484	total: 298ms	remaining: 727ms
# 291:	learn: 0.3761367	total: 299ms	remaining: 725ms
# 292:	learn: 0.3760058	total: 299ms	remaining: 722ms
# 293:	learn: 0.3758563	total: 300ms	remaining: 720ms
# 294:	learn: 0.3757544	total: 301ms	remaining: 718ms
# 295:	learn: 0.3755744	total: 301ms	remaining: 716ms
# 296:	learn: 0.3754731	total: 302ms	remaining: 714ms
# 297:	learn: 0.3752211	total: 302ms	remaining: 712ms
# 298:	learn: 0.3750157	total: 303ms	remaining: 710ms
# 299:	learn: 0.3746821	total: 303ms	remaining: 708ms
# 300:	learn: 0.3744700	total: 304ms	remaining: 706ms
# 301:	learn: 0.3743621	total: 304ms	remaining: 704ms
# 302:	learn: 0.3742629	total: 305ms	remaining: 702ms
# 303:	learn: 0.3740140	total: 306ms	remaining: 699ms
# 304:	learn: 0.3739639	total: 306ms	remaining: 697ms
# 305:	learn: 0.3738916	total: 306ms	remaining: 695ms
# 306:	learn: 0.3737550	total: 307ms	remaining: 693ms
# 307:	learn: 0.3735736	total: 308ms	remaining: 691ms
# 308:	learn: 0.3733476	total: 308ms	remaining: 689ms
# 309:	learn: 0.3732403	total: 309ms	remaining: 687ms
# 310:	learn: 0.3730867	total: 309ms	remaining: 685ms
# 311:	learn: 0.3729319	total: 310ms	remaining: 683ms
# 312:	learn: 0.3728004	total: 311ms	remaining: 682ms
# 313:	learn: 0.3727705	total: 311ms	remaining: 679ms
# 314:	learn: 0.3725333	total: 312ms	remaining: 678ms
# 315:	learn: 0.3725049	total: 312ms	remaining: 676ms
# 316:	learn: 0.3723757	total: 313ms	remaining: 674ms
# 317:	learn: 0.3721984	total: 313ms	remaining: 672ms
# 318:	learn: 0.3720906	total: 314ms	remaining: 670ms
# 319:	learn: 0.3720130	total: 314ms	remaining: 668ms
# 320:	learn: 0.3720056	total: 315ms	remaining: 665ms
# 321:	learn: 0.3718795	total: 315ms	remaining: 664ms
# 322:	learn: 0.3717683	total: 316ms	remaining: 662ms
# 323:	learn: 0.3715603	total: 316ms	remaining: 660ms
# 324:	learn: 0.3713254	total: 317ms	remaining: 659ms
# 325:	learn: 0.3712031	total: 318ms	remaining: 657ms
# 326:	learn: 0.3710829	total: 319ms	remaining: 656ms
# 327:	learn: 0.3709119	total: 319ms	remaining: 654ms
# 328:	learn: 0.3708055	total: 320ms	remaining: 653ms
# 329:	learn: 0.3705354	total: 321ms	remaining: 651ms
# 330:	learn: 0.3705029	total: 321ms	remaining: 649ms
# 331:	learn: 0.3704250	total: 322ms	remaining: 648ms
# 332:	learn: 0.3703466	total: 322ms	remaining: 646ms
# 333:	learn: 0.3703214	total: 323ms	remaining: 644ms
# 334:	learn: 0.3702593	total: 323ms	remaining: 642ms
# 335:	learn: 0.3699858	total: 324ms	remaining: 640ms
# 336:	learn: 0.3699031	total: 324ms	remaining: 638ms
# 337:	learn: 0.3698593	total: 325ms	remaining: 637ms
# 338:	learn: 0.3698283	total: 325ms	remaining: 635ms
# 339:	learn: 0.3696942	total: 326ms	remaining: 633ms
# 340:	learn: 0.3695300	total: 327ms	remaining: 631ms
# 341:	learn: 0.3693934	total: 327ms	remaining: 629ms
# 342:	learn: 0.3691682	total: 328ms	remaining: 628ms
# 343:	learn: 0.3690347	total: 328ms	remaining: 626ms
# 344:	learn: 0.3689192	total: 329ms	remaining: 624ms
# 345:	learn: 0.3688032	total: 329ms	remaining: 622ms
# 346:	learn: 0.3686560	total: 330ms	remaining: 621ms
# 347:	learn: 0.3685358	total: 330ms	remaining: 619ms
# 348:	learn: 0.3683937	total: 331ms	remaining: 617ms
# 349:	learn: 0.3682715	total: 332ms	remaining: 616ms
# 350:	learn: 0.3681789	total: 332ms	remaining: 614ms
# 351:	learn: 0.3679654	total: 333ms	remaining: 612ms
# 352:	learn: 0.3678394	total: 333ms	remaining: 611ms
# 353:	learn: 0.3677684	total: 334ms	remaining: 609ms
# 354:	learn: 0.3675766	total: 334ms	remaining: 608ms
# 355:	learn: 0.3674394	total: 335ms	remaining: 606ms
# 356:	learn: 0.3672819	total: 336ms	remaining: 604ms
# 357:	learn: 0.3671828	total: 336ms	remaining: 603ms
# 358:	learn: 0.3671437	total: 337ms	remaining: 601ms
# 359:	learn: 0.3669901	total: 337ms	remaining: 600ms
# 360:	learn: 0.3667962	total: 338ms	remaining: 598ms
# 361:	learn: 0.3666311	total: 339ms	remaining: 597ms
# 362:	learn: 0.3665471	total: 339ms	remaining: 596ms
# 363:	learn: 0.3665024	total: 340ms	remaining: 594ms
# 364:	learn: 0.3664910	total: 340ms	remaining: 592ms
# 365:	learn: 0.3663734	total: 341ms	remaining: 590ms
# 366:	learn: 0.3663228	total: 341ms	remaining: 589ms
# 367:	learn: 0.3661384	total: 342ms	remaining: 587ms
# 368:	learn: 0.3660742	total: 343ms	remaining: 586ms
# 369:	learn: 0.3659813	total: 343ms	remaining: 584ms
# 370:	learn: 0.3659683	total: 344ms	remaining: 583ms
# 371:	learn: 0.3658331	total: 344ms	remaining: 581ms
# 372:	learn: 0.3656512	total: 345ms	remaining: 579ms
# 373:	learn: 0.3654969	total: 345ms	remaining: 578ms
# 374:	learn: 0.3652907	total: 346ms	remaining: 577ms
# 375:	learn: 0.3652250	total: 347ms	remaining: 575ms
# 376:	learn: 0.3650371	total: 347ms	remaining: 574ms
# 377:	learn: 0.3649217	total: 348ms	remaining: 572ms
# 378:	learn: 0.3648637	total: 348ms	remaining: 571ms
# 379:	learn: 0.3648310	total: 349ms	remaining: 569ms
# 380:	learn: 0.3647633	total: 349ms	remaining: 568ms
# 381:	learn: 0.3646548	total: 350ms	remaining: 566ms
# 382:	learn: 0.3645251	total: 350ms	remaining: 565ms
# 383:	learn: 0.3643581	total: 351ms	remaining: 563ms
# 384:	learn: 0.3642852	total: 352ms	remaining: 562ms
# 385:	learn: 0.3642166	total: 352ms	remaining: 560ms
# 386:	learn: 0.3641357	total: 353ms	remaining: 559ms
# 387:	learn: 0.3640682	total: 353ms	remaining: 557ms
# 388:	learn: 0.3638551	total: 354ms	remaining: 557ms
# 389:	learn: 0.3638218	total: 355ms	remaining: 556ms
# 390:	learn: 0.3637049	total: 356ms	remaining: 554ms
# 391:	learn: 0.3636019	total: 357ms	remaining: 553ms
# 392:	learn: 0.3633956	total: 357ms	remaining: 552ms
# 393:	learn: 0.3632914	total: 358ms	remaining: 550ms
# 394:	learn: 0.3632587	total: 358ms	remaining: 549ms
# 395:	learn: 0.3630456	total: 359ms	remaining: 547ms
# 396:	learn: 0.3628806	total: 359ms	remaining: 546ms
# 397:	learn: 0.3627320	total: 360ms	remaining: 544ms
# 398:	learn: 0.3626711	total: 361ms	remaining: 543ms
# 399:	learn: 0.3624974	total: 361ms	remaining: 542ms
# 400:	learn: 0.3624749	total: 362ms	remaining: 540ms
# 401:	learn: 0.3624186	total: 362ms	remaining: 539ms
# 402:	learn: 0.3623845	total: 363ms	remaining: 537ms
# 403:	learn: 0.3622899	total: 363ms	remaining: 536ms
# 404:	learn: 0.3619672	total: 364ms	remaining: 534ms
# 405:	learn: 0.3619202	total: 364ms	remaining: 533ms
# 406:	learn: 0.3618567	total: 365ms	remaining: 532ms
# 407:	learn: 0.3617752	total: 365ms	remaining: 530ms
# 408:	learn: 0.3616343	total: 366ms	remaining: 529ms
# 409:	learn: 0.3616114	total: 366ms	remaining: 527ms
# 410:	learn: 0.3615010	total: 367ms	remaining: 526ms
# 411:	learn: 0.3614931	total: 367ms	remaining: 524ms
# 412:	learn: 0.3613946	total: 368ms	remaining: 523ms
# 413:	learn: 0.3613689	total: 368ms	remaining: 522ms
# 414:	learn: 0.3612138	total: 369ms	remaining: 520ms
# 415:	learn: 0.3610761	total: 370ms	remaining: 519ms
# 416:	learn: 0.3610196	total: 370ms	remaining: 518ms
# 417:	learn: 0.3610067	total: 371ms	remaining: 516ms
# 418:	learn: 0.3609629	total: 371ms	remaining: 515ms
# 419:	learn: 0.3609236	total: 372ms	remaining: 514ms
# 420:	learn: 0.3606789	total: 373ms	remaining: 512ms
# 421:	learn: 0.3606242	total: 373ms	remaining: 511ms
# 422:	learn: 0.3605439	total: 374ms	remaining: 510ms
# 423:	learn: 0.3604177	total: 374ms	remaining: 509ms
# 424:	learn: 0.3602964	total: 375ms	remaining: 507ms
# 425:	learn: 0.3601288	total: 375ms	remaining: 506ms
# 426:	learn: 0.3600894	total: 376ms	remaining: 505ms
# 427:	learn: 0.3598597	total: 377ms	remaining: 503ms
# 428:	learn: 0.3598328	total: 377ms	remaining: 502ms
# 429:	learn: 0.3598285	total: 378ms	remaining: 500ms
# 430:	learn: 0.3597534	total: 378ms	remaining: 499ms
# 431:	learn: 0.3596425	total: 379ms	remaining: 498ms
# 432:	learn: 0.3596287	total: 379ms	remaining: 496ms
# 433:	learn: 0.3594312	total: 380ms	remaining: 495ms
# 434:	learn: 0.3593040	total: 380ms	remaining: 494ms
# 435:	learn: 0.3591931	total: 381ms	remaining: 493ms
# 436:	learn: 0.3590986	total: 382ms	remaining: 492ms
# 437:	learn: 0.3590905	total: 382ms	remaining: 490ms
# 438:	learn: 0.3589928	total: 383ms	remaining: 489ms
# 439:	learn: 0.3589696	total: 383ms	remaining: 488ms
# 440:	learn: 0.3588928	total: 384ms	remaining: 487ms
# 441:	learn: 0.3587889	total: 385ms	remaining: 486ms
# 442:	learn: 0.3587608	total: 386ms	remaining: 485ms
# 443:	learn: 0.3586495	total: 387ms	remaining: 485ms
# 444:	learn: 0.3585785	total: 389ms	remaining: 485ms
# 445:	learn: 0.3584178	total: 390ms	remaining: 484ms
# 446:	learn: 0.3583465	total: 391ms	remaining: 484ms
# 447:	learn: 0.3581922	total: 393ms	remaining: 484ms
# 448:	learn: 0.3580916	total: 394ms	remaining: 483ms
# 449:	learn: 0.3580106	total: 395ms	remaining: 483ms
# 450:	learn: 0.3579639	total: 397ms	remaining: 483ms
# 451:	learn: 0.3579384	total: 398ms	remaining: 482ms
# 452:	learn: 0.3577539	total: 399ms	remaining: 482ms
# 453:	learn: 0.3577420	total: 400ms	remaining: 481ms
# 454:	learn: 0.3576791	total: 401ms	remaining: 481ms
# 455:	learn: 0.3576609	total: 402ms	remaining: 480ms
# 456:	learn: 0.3575790	total: 404ms	remaining: 480ms
# 457:	learn: 0.3575088	total: 405ms	remaining: 479ms
# 458:	learn: 0.3574230	total: 406ms	remaining: 479ms
# 459:	learn: 0.3574104	total: 407ms	remaining: 478ms
# 460:	learn: 0.3573614	total: 409ms	remaining: 478ms
# 461:	learn: 0.3571285	total: 410ms	remaining: 477ms
# 462:	learn: 0.3570796	total: 411ms	remaining: 477ms
# 463:	learn: 0.3569759	total: 413ms	remaining: 477ms
# 464:	learn: 0.3568834	total: 414ms	remaining: 476ms
# 465:	learn: 0.3568011	total: 415ms	remaining: 476ms
# 466:	learn: 0.3567420	total: 417ms	remaining: 476ms
# 467:	learn: 0.3566262	total: 418ms	remaining: 475ms
# 468:	learn: 0.3565153	total: 419ms	remaining: 475ms
# 469:	learn: 0.3564076	total: 421ms	remaining: 475ms
# 470:	learn: 0.3563185	total: 422ms	remaining: 474ms
# 471:	learn: 0.3562601	total: 424ms	remaining: 474ms
# 472:	learn: 0.3562485	total: 425ms	remaining: 473ms
# 473:	learn: 0.3562323	total: 426ms	remaining: 473ms
# 474:	learn: 0.3560507	total: 427ms	remaining: 472ms
# 475:	learn: 0.3559520	total: 428ms	remaining: 471ms
# 476:	learn: 0.3558546	total: 428ms	remaining: 470ms
# 477:	learn: 0.3557939	total: 429ms	remaining: 468ms
# 478:	learn: 0.3556563	total: 429ms	remaining: 467ms
# 479:	learn: 0.3556072	total: 430ms	remaining: 466ms
# 480:	learn: 0.3555938	total: 430ms	remaining: 464ms
# 481:	learn: 0.3554654	total: 431ms	remaining: 463ms
# 482:	learn: 0.3553799	total: 431ms	remaining: 462ms
# 483:	learn: 0.3553040	total: 432ms	remaining: 461ms
# 484:	learn: 0.3551470	total: 433ms	remaining: 460ms
# 485:	learn: 0.3550492	total: 434ms	remaining: 458ms
# 486:	learn: 0.3550094	total: 434ms	remaining: 457ms
# 487:	learn: 0.3549705	total: 435ms	remaining: 456ms
# 488:	learn: 0.3549031	total: 435ms	remaining: 455ms
# 489:	learn: 0.3549020	total: 436ms	remaining: 453ms
# 490:	learn: 0.3547760	total: 436ms	remaining: 452ms
# 491:	learn: 0.3546781	total: 437ms	remaining: 451ms
# 492:	learn: 0.3545743	total: 437ms	remaining: 450ms
# 493:	learn: 0.3543945	total: 438ms	remaining: 448ms
# 494:	learn: 0.3543763	total: 438ms	remaining: 447ms
# 495:	learn: 0.3542860	total: 439ms	remaining: 446ms
# 496:	learn: 0.3542354	total: 439ms	remaining: 445ms
# 497:	learn: 0.3541137	total: 440ms	remaining: 443ms
# 498:	learn: 0.3539506	total: 440ms	remaining: 442ms
# 499:	learn: 0.3539275	total: 441ms	remaining: 441ms
# 500:	learn: 0.3537728	total: 441ms	remaining: 440ms
# 501:	learn: 0.3536200	total: 442ms	remaining: 438ms
# 502:	learn: 0.3533987	total: 443ms	remaining: 437ms
# 503:	learn: 0.3532396	total: 443ms	remaining: 436ms
# 504:	learn: 0.3532220	total: 444ms	remaining: 435ms
# 505:	learn: 0.3530771	total: 444ms	remaining: 434ms
# 506:	learn: 0.3530444	total: 445ms	remaining: 432ms
# 507:	learn: 0.3529853	total: 445ms	remaining: 431ms
# 508:	learn: 0.3528686	total: 446ms	remaining: 430ms
# 509:	learn: 0.3526375	total: 447ms	remaining: 429ms
# 510:	learn: 0.3524421	total: 447ms	remaining: 428ms
# 511:	learn: 0.3521982	total: 448ms	remaining: 427ms
# 512:	learn: 0.3521472	total: 448ms	remaining: 426ms
# 513:	learn: 0.3520936	total: 449ms	remaining: 425ms
# 514:	learn: 0.3520021	total: 450ms	remaining: 423ms
# 515:	learn: 0.3519124	total: 450ms	remaining: 422ms
# 516:	learn: 0.3518743	total: 451ms	remaining: 421ms
# 517:	learn: 0.3517616	total: 451ms	remaining: 420ms
# 518:	learn: 0.3516999	total: 452ms	remaining: 419ms
# 519:	learn: 0.3516292	total: 453ms	remaining: 418ms
# 520:	learn: 0.3516264	total: 453ms	remaining: 416ms
# 521:	learn: 0.3514917	total: 453ms	remaining: 415ms
# 522:	learn: 0.3514256	total: 454ms	remaining: 414ms
# 523:	learn: 0.3514080	total: 455ms	remaining: 413ms
# 524:	learn: 0.3514074	total: 455ms	remaining: 412ms
# 525:	learn: 0.3513286	total: 455ms	remaining: 410ms
# 526:	learn: 0.3510696	total: 456ms	remaining: 409ms
# 527:	learn: 0.3509644	total: 457ms	remaining: 408ms
# 528:	learn: 0.3509197	total: 457ms	remaining: 407ms
# 529:	learn: 0.3507779	total: 458ms	remaining: 406ms
# 530:	learn: 0.3507436	total: 458ms	remaining: 405ms
# 531:	learn: 0.3506775	total: 459ms	remaining: 404ms
# 532:	learn: 0.3506746	total: 459ms	remaining: 402ms
# 533:	learn: 0.3506161	total: 460ms	remaining: 401ms
# 534:	learn: 0.3505516	total: 460ms	remaining: 400ms
# 535:	learn: 0.3503838	total: 461ms	remaining: 399ms
# 536:	learn: 0.3503266	total: 462ms	remaining: 398ms
# 537:	learn: 0.3502835	total: 462ms	remaining: 397ms
# 538:	learn: 0.3501744	total: 463ms	remaining: 396ms
# 539:	learn: 0.3501643	total: 463ms	remaining: 394ms
# 540:	learn: 0.3501596	total: 463ms	remaining: 393ms
# 541:	learn: 0.3500815	total: 464ms	remaining: 392ms
# 542:	learn: 0.3500538	total: 465ms	remaining: 391ms
# 543:	learn: 0.3500401	total: 465ms	remaining: 390ms
# 544:	learn: 0.3499341	total: 466ms	remaining: 389ms
# 545:	learn: 0.3498869	total: 466ms	remaining: 388ms
# 546:	learn: 0.3498307	total: 467ms	remaining: 386ms
# 547:	learn: 0.3498064	total: 467ms	remaining: 385ms
# 548:	learn: 0.3496349	total: 468ms	remaining: 385ms
# 549:	learn: 0.3495988	total: 469ms	remaining: 384ms
# 550:	learn: 0.3495964	total: 469ms	remaining: 382ms
# 551:	learn: 0.3495044	total: 470ms	remaining: 381ms
# 552:	learn: 0.3494870	total: 470ms	remaining: 380ms
# 553:	learn: 0.3493569	total: 471ms	remaining: 379ms
# 554:	learn: 0.3492762	total: 472ms	remaining: 378ms
# 555:	learn: 0.3492056	total: 472ms	remaining: 377ms
# 556:	learn: 0.3490737	total: 473ms	remaining: 376ms
# 557:	learn: 0.3490035	total: 473ms	remaining: 375ms
# 558:	learn: 0.3489453	total: 474ms	remaining: 374ms
# 559:	learn: 0.3487938	total: 474ms	remaining: 373ms
# 560:	learn: 0.3486675	total: 475ms	remaining: 372ms
# 561:	learn: 0.3486397	total: 476ms	remaining: 371ms
# 562:	learn: 0.3485708	total: 476ms	remaining: 370ms
# 563:	learn: 0.3484387	total: 477ms	remaining: 369ms
# 564:	learn: 0.3482610	total: 477ms	remaining: 367ms
# 565:	learn: 0.3482376	total: 478ms	remaining: 366ms
# 566:	learn: 0.3481718	total: 478ms	remaining: 365ms
# 567:	learn: 0.3480526	total: 479ms	remaining: 364ms
# 568:	learn: 0.3479530	total: 480ms	remaining: 363ms
# 569:	learn: 0.3478978	total: 480ms	remaining: 362ms
# 570:	learn: 0.3478708	total: 481ms	remaining: 361ms
# 571:	learn: 0.3478203	total: 481ms	remaining: 360ms
# 572:	learn: 0.3477531	total: 482ms	remaining: 359ms
# 573:	learn: 0.3476734	total: 482ms	remaining: 358ms
# 574:	learn: 0.3475513	total: 483ms	remaining: 357ms
# 575:	learn: 0.3474737	total: 484ms	remaining: 356ms
# 576:	learn: 0.3474268	total: 484ms	remaining: 355ms
# 577:	learn: 0.3473299	total: 485ms	remaining: 354ms
# 578:	learn: 0.3473191	total: 485ms	remaining: 353ms
# 579:	learn: 0.3473174	total: 485ms	remaining: 352ms
# 580:	learn: 0.3471791	total: 486ms	remaining: 351ms
# 581:	learn: 0.3471310	total: 487ms	remaining: 349ms
# 582:	learn: 0.3471052	total: 487ms	remaining: 348ms
# 583:	learn: 0.3470409	total: 488ms	remaining: 347ms
# 584:	learn: 0.3469830	total: 488ms	remaining: 346ms
# 585:	learn: 0.3469632	total: 489ms	remaining: 345ms
# 586:	learn: 0.3469533	total: 489ms	remaining: 344ms
# 587:	learn: 0.3468781	total: 490ms	remaining: 343ms
# 588:	learn: 0.3467917	total: 490ms	remaining: 342ms
# 589:	learn: 0.3463669	total: 491ms	remaining: 341ms
# 590:	learn: 0.3463232	total: 492ms	remaining: 340ms
# 591:	learn: 0.3462320	total: 492ms	remaining: 339ms
# 592:	learn: 0.3462204	total: 493ms	remaining: 338ms
# 593:	learn: 0.3461189	total: 493ms	remaining: 337ms
# 594:	learn: 0.3460463	total: 494ms	remaining: 336ms
# 595:	learn: 0.3459260	total: 494ms	remaining: 335ms
# 596:	learn: 0.3458261	total: 495ms	remaining: 334ms
# 597:	learn: 0.3456898	total: 496ms	remaining: 333ms
# 598:	learn: 0.3456518	total: 496ms	remaining: 332ms
# 599:	learn: 0.3455564	total: 497ms	remaining: 331ms
# 600:	learn: 0.3454770	total: 497ms	remaining: 330ms
# 601:	learn: 0.3454710	total: 498ms	remaining: 329ms
# 602:	learn: 0.3452959	total: 498ms	remaining: 328ms
# 603:	learn: 0.3452814	total: 499ms	remaining: 327ms
# 604:	learn: 0.3450988	total: 499ms	remaining: 326ms
# 605:	learn: 0.3450491	total: 500ms	remaining: 325ms
# 606:	learn: 0.3448637	total: 501ms	remaining: 324ms
# 607:	learn: 0.3446968	total: 501ms	remaining: 323ms
# 608:	learn: 0.3446419	total: 502ms	remaining: 322ms
# 609:	learn: 0.3445025	total: 502ms	remaining: 321ms
# 610:	learn: 0.3443971	total: 503ms	remaining: 320ms
# 611:	learn: 0.3443155	total: 503ms	remaining: 319ms
# 612:	learn: 0.3442751	total: 504ms	remaining: 318ms
# 613:	learn: 0.3441761	total: 505ms	remaining: 317ms
# 614:	learn: 0.3441338	total: 505ms	remaining: 316ms
# 615:	learn: 0.3441224	total: 506ms	remaining: 315ms
# 616:	learn: 0.3440348	total: 506ms	remaining: 314ms
# 617:	learn: 0.3439768	total: 507ms	remaining: 313ms
# 618:	learn: 0.3438388	total: 508ms	remaining: 312ms
# 619:	learn: 0.3437556	total: 508ms	remaining: 312ms
# 620:	learn: 0.3437486	total: 509ms	remaining: 310ms
# 621:	learn: 0.3437091	total: 509ms	remaining: 310ms
# 622:	learn: 0.3436071	total: 510ms	remaining: 309ms
# 623:	learn: 0.3435084	total: 511ms	remaining: 308ms
# 624:	learn: 0.3434408	total: 511ms	remaining: 307ms
# 625:	learn: 0.3434026	total: 512ms	remaining: 306ms
# 626:	learn: 0.3432753	total: 512ms	remaining: 305ms
# 627:	learn: 0.3431646	total: 513ms	remaining: 304ms
# 628:	learn: 0.3430777	total: 514ms	remaining: 303ms
# 629:	learn: 0.3428962	total: 514ms	remaining: 302ms
# 630:	learn: 0.3428816	total: 515ms	remaining: 301ms
# 631:	learn: 0.3428574	total: 515ms	remaining: 300ms
# 632:	learn: 0.3428347	total: 516ms	remaining: 299ms
# 633:	learn: 0.3426640	total: 516ms	remaining: 298ms
# 634:	learn: 0.3425587	total: 517ms	remaining: 297ms
# 635:	learn: 0.3425320	total: 517ms	remaining: 296ms
# 636:	learn: 0.3424796	total: 518ms	remaining: 295ms
# 637:	learn: 0.3423655	total: 518ms	remaining: 294ms
# 638:	learn: 0.3422831	total: 519ms	remaining: 293ms
# 639:	learn: 0.3421560	total: 520ms	remaining: 292ms
# 640:	learn: 0.3420757	total: 520ms	remaining: 291ms
# 641:	learn: 0.3419145	total: 521ms	remaining: 291ms
# 642:	learn: 0.3418550	total: 522ms	remaining: 290ms
# 643:	learn: 0.3418109	total: 522ms	remaining: 289ms
# 644:	learn: 0.3417939	total: 523ms	remaining: 288ms
# 645:	learn: 0.3417271	total: 523ms	remaining: 287ms
# 646:	learn: 0.3417101	total: 523ms	remaining: 286ms
# 647:	learn: 0.3417016	total: 524ms	remaining: 285ms
# 648:	learn: 0.3416454	total: 524ms	remaining: 284ms
# 649:	learn: 0.3416247	total: 525ms	remaining: 283ms
# 650:	learn: 0.3415747	total: 525ms	remaining: 282ms
# 651:	learn: 0.3415110	total: 526ms	remaining: 281ms
# 652:	learn: 0.3414313	total: 527ms	remaining: 280ms
# 653:	learn: 0.3411965	total: 527ms	remaining: 279ms
# 654:	learn: 0.3410731	total: 528ms	remaining: 278ms
# 655:	learn: 0.3409985	total: 528ms	remaining: 277ms
# 656:	learn: 0.3409495	total: 529ms	remaining: 276ms
# 657:	learn: 0.3407063	total: 530ms	remaining: 275ms
# 658:	learn: 0.3406023	total: 530ms	remaining: 274ms
# 659:	learn: 0.3405938	total: 531ms	remaining: 273ms
# 660:	learn: 0.3405284	total: 531ms	remaining: 272ms
# 661:	learn: 0.3404663	total: 532ms	remaining: 272ms
# 662:	learn: 0.3403091	total: 533ms	remaining: 271ms
# 663:	learn: 0.3402822	total: 533ms	remaining: 270ms
# 664:	learn: 0.3402400	total: 534ms	remaining: 269ms
# 665:	learn: 0.3401500	total: 534ms	remaining: 268ms
# 666:	learn: 0.3400788	total: 535ms	remaining: 267ms
# 667:	learn: 0.3399732	total: 535ms	remaining: 266ms
# 668:	learn: 0.3397741	total: 536ms	remaining: 265ms
# 669:	learn: 0.3396784	total: 537ms	remaining: 264ms
# 670:	learn: 0.3396114	total: 537ms	remaining: 263ms
# 671:	learn: 0.3395503	total: 538ms	remaining: 263ms
# 672:	learn: 0.3394592	total: 539ms	remaining: 262ms
# 673:	learn: 0.3393464	total: 539ms	remaining: 261ms
# 674:	learn: 0.3392715	total: 540ms	remaining: 260ms
# 675:	learn: 0.3391727	total: 540ms	remaining: 259ms
# 676:	learn: 0.3391390	total: 541ms	remaining: 258ms
# 677:	learn: 0.3389694	total: 541ms	remaining: 257ms
# 678:	learn: 0.3389617	total: 542ms	remaining: 256ms
# 679:	learn: 0.3389377	total: 543ms	remaining: 255ms
# 680:	learn: 0.3388907	total: 543ms	remaining: 254ms
# 681:	learn: 0.3388572	total: 544ms	remaining: 254ms
# 682:	learn: 0.3386867	total: 544ms	remaining: 253ms
# 683:	learn: 0.3386231	total: 545ms	remaining: 252ms
# 684:	learn: 0.3385786	total: 546ms	remaining: 251ms
# 685:	learn: 0.3384493	total: 546ms	remaining: 250ms
# 686:	learn: 0.3382573	total: 547ms	remaining: 249ms
# 687:	learn: 0.3379693	total: 547ms	remaining: 248ms
# 688:	learn: 0.3377422	total: 548ms	remaining: 247ms
# 689:	learn: 0.3376092	total: 549ms	remaining: 246ms
# 690:	learn: 0.3375848	total: 550ms	remaining: 246ms
# 691:	learn: 0.3374405	total: 551ms	remaining: 245ms
# 692:	learn: 0.3373310	total: 555ms	remaining: 246ms
# 693:	learn: 0.3371611	total: 555ms	remaining: 245ms
# 694:	learn: 0.3371587	total: 556ms	remaining: 244ms
# 695:	learn: 0.3370297	total: 556ms	remaining: 243ms
# 696:	learn: 0.3368585	total: 557ms	remaining: 242ms
# 697:	learn: 0.3368517	total: 557ms	remaining: 241ms
# 698:	learn: 0.3367821	total: 558ms	remaining: 240ms
# 699:	learn: 0.3365899	total: 558ms	remaining: 239ms
# 700:	learn: 0.3365599	total: 559ms	remaining: 238ms
# 701:	learn: 0.3364302	total: 560ms	remaining: 238ms
# 702:	learn: 0.3362129	total: 560ms	remaining: 237ms
# 703:	learn: 0.3361032	total: 561ms	remaining: 236ms
# 704:	learn: 0.3360279	total: 561ms	remaining: 235ms
# 705:	learn: 0.3358664	total: 562ms	remaining: 234ms
# 706:	learn: 0.3357474	total: 562ms	remaining: 233ms
# 707:	learn: 0.3357386	total: 563ms	remaining: 232ms
# 708:	learn: 0.3356430	total: 563ms	remaining: 231ms
# 709:	learn: 0.3356178	total: 564ms	remaining: 230ms
# 710:	learn: 0.3355032	total: 564ms	remaining: 229ms
# 711:	learn: 0.3354956	total: 565ms	remaining: 228ms
# 712:	learn: 0.3354230	total: 565ms	remaining: 228ms
# 713:	learn: 0.3353618	total: 566ms	remaining: 227ms
# 714:	learn: 0.3353205	total: 566ms	remaining: 226ms
# 715:	learn: 0.3351270	total: 567ms	remaining: 225ms
# 716:	learn: 0.3349455	total: 568ms	remaining: 224ms
# 717:	learn: 0.3349238	total: 568ms	remaining: 223ms
# 718:	learn: 0.3348644	total: 569ms	remaining: 222ms
# 719:	learn: 0.3348297	total: 569ms	remaining: 221ms
# 720:	learn: 0.3348256	total: 570ms	remaining: 220ms
# 721:	learn: 0.3347870	total: 570ms	remaining: 220ms
# 722:	learn: 0.3347317	total: 571ms	remaining: 219ms
# 723:	learn: 0.3345844	total: 571ms	remaining: 218ms
# 724:	learn: 0.3344253	total: 572ms	remaining: 217ms
# 725:	learn: 0.3343455	total: 572ms	remaining: 216ms
# 726:	learn: 0.3342337	total: 573ms	remaining: 215ms
# 727:	learn: 0.3340763	total: 574ms	remaining: 215ms
# 728:	learn: 0.3340225	total: 575ms	remaining: 214ms
# 729:	learn: 0.3338927	total: 576ms	remaining: 213ms
# 730:	learn: 0.3338377	total: 577ms	remaining: 212ms
# 731:	learn: 0.3336705	total: 578ms	remaining: 212ms
# 732:	learn: 0.3335857	total: 578ms	remaining: 211ms
# 733:	learn: 0.3335515	total: 579ms	remaining: 210ms
# 734:	learn: 0.3334744	total: 580ms	remaining: 209ms
# 735:	learn: 0.3334459	total: 580ms	remaining: 208ms
# 736:	learn: 0.3334398	total: 581ms	remaining: 207ms
# 737:	learn: 0.3331115	total: 581ms	remaining: 206ms
# 738:	learn: 0.3331057	total: 582ms	remaining: 205ms
# 739:	learn: 0.3330273	total: 582ms	remaining: 205ms
# 740:	learn: 0.3329461	total: 583ms	remaining: 204ms
# 741:	learn: 0.3328436	total: 583ms	remaining: 203ms
# 742:	learn: 0.3327768	total: 584ms	remaining: 202ms
# 743:	learn: 0.3327524	total: 584ms	remaining: 201ms
# 744:	learn: 0.3326512	total: 585ms	remaining: 200ms
# 745:	learn: 0.3325559	total: 586ms	remaining: 199ms
# 746:	learn: 0.3324561	total: 586ms	remaining: 199ms
# 747:	learn: 0.3323839	total: 587ms	remaining: 198ms
# 748:	learn: 0.3323544	total: 587ms	remaining: 197ms
# 749:	learn: 0.3322984	total: 588ms	remaining: 196ms
# 750:	learn: 0.3322672	total: 588ms	remaining: 195ms
# 751:	learn: 0.3322168	total: 589ms	remaining: 194ms
# 752:	learn: 0.3320787	total: 590ms	remaining: 193ms
# 753:	learn: 0.3319945	total: 590ms	remaining: 193ms
# 754:	learn: 0.3319242	total: 591ms	remaining: 192ms
# 755:	learn: 0.3318612	total: 591ms	remaining: 191ms
# 756:	learn: 0.3318147	total: 592ms	remaining: 190ms
# 757:	learn: 0.3317732	total: 592ms	remaining: 189ms
# 758:	learn: 0.3316453	total: 593ms	remaining: 188ms
# 759:	learn: 0.3316441	total: 593ms	remaining: 187ms
# 760:	learn: 0.3315721	total: 594ms	remaining: 187ms
# 761:	learn: 0.3315615	total: 594ms	remaining: 186ms
# 762:	learn: 0.3314967	total: 595ms	remaining: 185ms
# 763:	learn: 0.3312431	total: 596ms	remaining: 184ms
# 764:	learn: 0.3312104	total: 596ms	remaining: 183ms
# 765:	learn: 0.3311471	total: 597ms	remaining: 182ms
# 766:	learn: 0.3310952	total: 597ms	remaining: 181ms
# 767:	learn: 0.3309649	total: 598ms	remaining: 181ms
# 768:	learn: 0.3309178	total: 598ms	remaining: 180ms
# 769:	learn: 0.3308774	total: 599ms	remaining: 179ms
# 770:	learn: 0.3308232	total: 600ms	remaining: 178ms
# 771:	learn: 0.3307520	total: 600ms	remaining: 177ms
# 772:	learn: 0.3307086	total: 601ms	remaining: 177ms
# 773:	learn: 0.3304576	total: 602ms	remaining: 176ms
# 774:	learn: 0.3303389	total: 602ms	remaining: 175ms
# 775:	learn: 0.3303081	total: 603ms	remaining: 174ms
# 776:	learn: 0.3302048	total: 603ms	remaining: 173ms
# 777:	learn: 0.3300389	total: 604ms	remaining: 172ms
# 778:	learn: 0.3299438	total: 605ms	remaining: 172ms
# 779:	learn: 0.3297913	total: 605ms	remaining: 171ms
# 780:	learn: 0.3296094	total: 606ms	remaining: 170ms
# 781:	learn: 0.3294765	total: 606ms	remaining: 169ms
# 782:	learn: 0.3294101	total: 607ms	remaining: 168ms
# 783:	learn: 0.3292082	total: 608ms	remaining: 167ms
# 784:	learn: 0.3291403	total: 608ms	remaining: 167ms
# 785:	learn: 0.3290828	total: 609ms	remaining: 166ms
# 786:	learn: 0.3290502	total: 609ms	remaining: 165ms
# 787:	learn: 0.3289901	total: 610ms	remaining: 164ms
# 788:	learn: 0.3287523	total: 610ms	remaining: 163ms
# 789:	learn: 0.3286979	total: 611ms	remaining: 162ms
# 790:	learn: 0.3285600	total: 611ms	remaining: 162ms
# 791:	learn: 0.3284172	total: 612ms	remaining: 161ms
# 792:	learn: 0.3283918	total: 613ms	remaining: 160ms
# 793:	learn: 0.3282515	total: 613ms	remaining: 159ms
# 794:	learn: 0.3282008	total: 614ms	remaining: 158ms
# 795:	learn: 0.3281230	total: 614ms	remaining: 157ms
# 796:	learn: 0.3281181	total: 615ms	remaining: 157ms
# 797:	learn: 0.3280198	total: 615ms	remaining: 156ms
# 798:	learn: 0.3279068	total: 616ms	remaining: 155ms
# 799:	learn: 0.3277424	total: 616ms	remaining: 154ms
# 800:	learn: 0.3277374	total: 617ms	remaining: 153ms
# 801:	learn: 0.3276059	total: 617ms	remaining: 152ms
# 802:	learn: 0.3275494	total: 618ms	remaining: 152ms
# 803:	learn: 0.3274741	total: 618ms	remaining: 151ms
# 804:	learn: 0.3273980	total: 619ms	remaining: 150ms
# 805:	learn: 0.3272647	total: 619ms	remaining: 149ms
# 806:	learn: 0.3272594	total: 620ms	remaining: 148ms
# 807:	learn: 0.3271807	total: 620ms	remaining: 147ms
# 808:	learn: 0.3270628	total: 621ms	remaining: 147ms
# 809:	learn: 0.3268782	total: 622ms	remaining: 146ms
# 810:	learn: 0.3268212	total: 622ms	remaining: 145ms
# 811:	learn: 0.3267621	total: 623ms	remaining: 144ms
# 812:	learn: 0.3266558	total: 624ms	remaining: 143ms
# 813:	learn: 0.3265507	total: 624ms	remaining: 143ms
# 814:	learn: 0.3265103	total: 625ms	remaining: 142ms
# 815:	learn: 0.3262676	total: 625ms	remaining: 141ms
# 816:	learn: 0.3261077	total: 626ms	remaining: 140ms
# 817:	learn: 0.3259934	total: 626ms	remaining: 139ms
# 818:	learn: 0.3257840	total: 627ms	remaining: 139ms
# 819:	learn: 0.3256440	total: 628ms	remaining: 138ms
# 820:	learn: 0.3255984	total: 628ms	remaining: 137ms
# 821:	learn: 0.3255210	total: 629ms	remaining: 136ms
# 822:	learn: 0.3254166	total: 629ms	remaining: 135ms
# 823:	learn: 0.3253638	total: 630ms	remaining: 135ms
# 824:	learn: 0.3253019	total: 630ms	remaining: 134ms
# 825:	learn: 0.3250868	total: 631ms	remaining: 133ms
# 826:	learn: 0.3250189	total: 631ms	remaining: 132ms
# 827:	learn: 0.3249226	total: 632ms	remaining: 131ms
# 828:	learn: 0.3247585	total: 633ms	remaining: 130ms
# 829:	learn: 0.3245950	total: 633ms	remaining: 130ms
# 830:	learn: 0.3245545	total: 634ms	remaining: 129ms
# 831:	learn: 0.3245494	total: 634ms	remaining: 128ms
# 832:	learn: 0.3244639	total: 635ms	remaining: 127ms
# 833:	learn: 0.3243928	total: 635ms	remaining: 126ms
# 834:	learn: 0.3242793	total: 636ms	remaining: 126ms
# 835:	learn: 0.3239869	total: 636ms	remaining: 125ms
# 836:	learn: 0.3239096	total: 637ms	remaining: 124ms
# 837:	learn: 0.3238588	total: 638ms	remaining: 123ms
# 838:	learn: 0.3238313	total: 638ms	remaining: 122ms
# 839:	learn: 0.3236572	total: 639ms	remaining: 122ms
# 840:	learn: 0.3235718	total: 639ms	remaining: 121ms
# 841:	learn: 0.3234978	total: 640ms	remaining: 120ms
# 842:	learn: 0.3234422	total: 640ms	remaining: 119ms
# 843:	learn: 0.3232631	total: 641ms	remaining: 118ms
# 844:	learn: 0.3231736	total: 642ms	remaining: 118ms
# 845:	learn: 0.3230192	total: 642ms	remaining: 117ms
# 846:	learn: 0.3227959	total: 643ms	remaining: 116ms
# 847:	learn: 0.3226847	total: 644ms	remaining: 115ms
# 848:	learn: 0.3226225	total: 644ms	remaining: 115ms
# 849:	learn: 0.3225474	total: 645ms	remaining: 114ms
# 850:	learn: 0.3224605	total: 645ms	remaining: 113ms
# 851:	learn: 0.3222189	total: 646ms	remaining: 112ms
# 852:	learn: 0.3221696	total: 646ms	remaining: 111ms
# 853:	learn: 0.3221113	total: 647ms	remaining: 111ms
# 854:	learn: 0.3220235	total: 647ms	remaining: 110ms
# 855:	learn: 0.3219549	total: 648ms	remaining: 109ms
# 856:	learn: 0.3218917	total: 649ms	remaining: 108ms
# 857:	learn: 0.3218092	total: 649ms	remaining: 107ms
# 858:	learn: 0.3217317	total: 650ms	remaining: 107ms
# 859:	learn: 0.3216172	total: 651ms	remaining: 106ms
# 860:	learn: 0.3216149	total: 651ms	remaining: 105ms
# 861:	learn: 0.3214838	total: 652ms	remaining: 104ms
# 862:	learn: 0.3214571	total: 652ms	remaining: 104ms
# 863:	learn: 0.3214041	total: 653ms	remaining: 103ms
# 864:	learn: 0.3213352	total: 653ms	remaining: 102ms
# 865:	learn: 0.3212665	total: 654ms	remaining: 101ms
# 866:	learn: 0.3211961	total: 655ms	remaining: 100ms
# 867:	learn: 0.3211311	total: 655ms	remaining: 99.6ms
# 868:	learn: 0.3209539	total: 656ms	remaining: 98.9ms
# 869:	learn: 0.3209008	total: 656ms	remaining: 98.1ms
# 870:	learn: 0.3208388	total: 657ms	remaining: 97.3ms
# 871:	learn: 0.3207839	total: 658ms	remaining: 96.5ms
# 872:	learn: 0.3206500	total: 658ms	remaining: 95.8ms
# 873:	learn: 0.3205152	total: 659ms	remaining: 95ms
# 874:	learn: 0.3204126	total: 659ms	remaining: 94.2ms
# 875:	learn: 0.3203276	total: 660ms	remaining: 93.4ms
# 876:	learn: 0.3202298	total: 661ms	remaining: 92.6ms
# 877:	learn: 0.3201740	total: 661ms	remaining: 91.9ms
# 878:	learn: 0.3200866	total: 662ms	remaining: 91.1ms
# 879:	learn: 0.3199712	total: 662ms	remaining: 90.3ms
# 880:	learn: 0.3198774	total: 663ms	remaining: 89.5ms
# 881:	learn: 0.3198372	total: 663ms	remaining: 88.8ms
# 882:	learn: 0.3198231	total: 664ms	remaining: 88ms
# 883:	learn: 0.3197717	total: 664ms	remaining: 87.2ms
# 884:	learn: 0.3197425	total: 665ms	remaining: 86.4ms
# 885:	learn: 0.3196784	total: 666ms	remaining: 85.7ms
# 886:	learn: 0.3195085	total: 666ms	remaining: 84.9ms
# 887:	learn: 0.3194746	total: 667ms	remaining: 84.1ms
# 888:	learn: 0.3194133	total: 668ms	remaining: 83.4ms
# 889:	learn: 0.3193656	total: 668ms	remaining: 82.6ms
# 890:	learn: 0.3191233	total: 669ms	remaining: 81.8ms
# 891:	learn: 0.3190939	total: 669ms	remaining: 81.1ms
# 892:	learn: 0.3190041	total: 670ms	remaining: 80.3ms
# 893:	learn: 0.3188447	total: 671ms	remaining: 79.5ms
# 894:	learn: 0.3186528	total: 672ms	remaining: 78.8ms
# 895:	learn: 0.3185829	total: 673ms	remaining: 78.1ms
# 896:	learn: 0.3185803	total: 673ms	remaining: 77.3ms
# 897:	learn: 0.3185038	total: 674ms	remaining: 76.6ms
# 898:	learn: 0.3184625	total: 675ms	remaining: 75.8ms
# 899:	learn: 0.3184091	total: 675ms	remaining: 75ms
# 900:	learn: 0.3182951	total: 676ms	remaining: 74.2ms
# 901:	learn: 0.3181669	total: 676ms	remaining: 73.5ms
# 902:	learn: 0.3181276	total: 677ms	remaining: 72.7ms
# 903:	learn: 0.3178952	total: 677ms	remaining: 71.9ms
# 904:	learn: 0.3178249	total: 678ms	remaining: 71.2ms
# 905:	learn: 0.3177377	total: 679ms	remaining: 70.4ms
# 906:	learn: 0.3176726	total: 679ms	remaining: 69.6ms
# 907:	learn: 0.3175860	total: 680ms	remaining: 68.9ms
# 908:	learn: 0.3175012	total: 680ms	remaining: 68.1ms
# 909:	learn: 0.3174309	total: 681ms	remaining: 67.3ms
# 910:	learn: 0.3173816	total: 681ms	remaining: 66.6ms
# 911:	learn: 0.3173021	total: 682ms	remaining: 65.8ms
# 912:	learn: 0.3172171	total: 683ms	remaining: 65ms
# 913:	learn: 0.3170765	total: 683ms	remaining: 64.3ms
# 914:	learn: 0.3170343	total: 684ms	remaining: 63.5ms
# 915:	learn: 0.3169979	total: 684ms	remaining: 62.8ms
# 916:	learn: 0.3168536	total: 685ms	remaining: 62ms
# 917:	learn: 0.3167863	total: 686ms	remaining: 61.2ms
# 918:	learn: 0.3167189	total: 686ms	remaining: 60.5ms
# 919:	learn: 0.3166141	total: 687ms	remaining: 59.7ms
# 920:	learn: 0.3165597	total: 687ms	remaining: 58.9ms
# 921:	learn: 0.3165366	total: 688ms	remaining: 58.2ms
# 922:	learn: 0.3164726	total: 688ms	remaining: 57.4ms
# 923:	learn: 0.3164208	total: 689ms	remaining: 56.7ms
# 924:	learn: 0.3163869	total: 690ms	remaining: 55.9ms
# 925:	learn: 0.3163525	total: 690ms	remaining: 55.1ms
# 926:	learn: 0.3162438	total: 691ms	remaining: 54.4ms
# 927:	learn: 0.3161399	total: 691ms	remaining: 53.6ms
# 928:	learn: 0.3160457	total: 692ms	remaining: 52.9ms
# 929:	learn: 0.3158997	total: 693ms	remaining: 52.1ms
# 930:	learn: 0.3157236	total: 693ms	remaining: 51.4ms
# 931:	learn: 0.3156047	total: 694ms	remaining: 50.6ms
# 932:	learn: 0.3154586	total: 695ms	remaining: 49.9ms
# 933:	learn: 0.3151959	total: 695ms	remaining: 49.1ms
# 934:	learn: 0.3150623	total: 696ms	remaining: 48.4ms
# 935:	learn: 0.3150122	total: 696ms	remaining: 47.6ms
# 936:	learn: 0.3149812	total: 697ms	remaining: 46.9ms
# 937:	learn: 0.3149504	total: 698ms	remaining: 46.1ms
# 938:	learn: 0.3149055	total: 698ms	remaining: 45.4ms
# 939:	learn: 0.3148267	total: 699ms	remaining: 44.6ms
# 940:	learn: 0.3147689	total: 699ms	remaining: 43.9ms
# 941:	learn: 0.3145626	total: 700ms	remaining: 43.1ms
# 942:	learn: 0.3145112	total: 701ms	remaining: 42.3ms
# 943:	learn: 0.3144929	total: 701ms	remaining: 41.6ms
# 944:	learn: 0.3144194	total: 702ms	remaining: 40.8ms
# 945:	learn: 0.3143868	total: 702ms	remaining: 40.1ms
# 946:	learn: 0.3143293	total: 703ms	remaining: 39.3ms
# 947:	learn: 0.3142759	total: 703ms	remaining: 38.6ms
# 948:	learn: 0.3142236	total: 704ms	remaining: 37.8ms
# 949:	learn: 0.3141974	total: 704ms	remaining: 37.1ms
# 950:	learn: 0.3141673	total: 705ms	remaining: 36.3ms
# 951:	learn: 0.3141109	total: 706ms	remaining: 35.6ms
# 952:	learn: 0.3139861	total: 706ms	remaining: 34.8ms
# 953:	learn: 0.3139014	total: 707ms	remaining: 34.1ms
# 954:	learn: 0.3138550	total: 708ms	remaining: 33.4ms
# 955:	learn: 0.3138119	total: 708ms	remaining: 32.6ms
# 956:	learn: 0.3137729	total: 709ms	remaining: 31.9ms
# 957:	learn: 0.3136702	total: 710ms	remaining: 31.1ms
# 958:	learn: 0.3136277	total: 710ms	remaining: 30.4ms
# 959:	learn: 0.3135719	total: 711ms	remaining: 29.6ms
# 960:	learn: 0.3135487	total: 711ms	remaining: 28.9ms
# 961:	learn: 0.3134751	total: 712ms	remaining: 28.1ms
# 962:	learn: 0.3134573	total: 712ms	remaining: 27.4ms
# 963:	learn: 0.3133562	total: 713ms	remaining: 26.6ms
# 964:	learn: 0.3132815	total: 714ms	remaining: 25.9ms
# 965:	learn: 0.3132166	total: 714ms	remaining: 25.1ms
# 966:	learn: 0.3131784	total: 715ms	remaining: 24.4ms
# 967:	learn: 0.3131143	total: 716ms	remaining: 23.7ms
# 968:	learn: 0.3130237	total: 716ms	remaining: 22.9ms
# 969:	learn: 0.3129570	total: 717ms	remaining: 22.2ms
# 970:	learn: 0.3127884	total: 717ms	remaining: 21.4ms
# 971:	learn: 0.3126320	total: 718ms	remaining: 20.7ms
# 972:	learn: 0.3126174	total: 718ms	remaining: 19.9ms
# 973:	learn: 0.3125179	total: 719ms	remaining: 19.2ms
# 974:	learn: 0.3124774	total: 720ms	remaining: 18.4ms
# 975:	learn: 0.3123141	total: 720ms	remaining: 17.7ms
# 976:	learn: 0.3121296	total: 721ms	remaining: 17ms
# 977:	learn: 0.3120630	total: 721ms	remaining: 16.2ms
# 978:	learn: 0.3119558	total: 722ms	remaining: 15.5ms
# 979:	learn: 0.3119367	total: 722ms	remaining: 14.7ms
# 980:	learn: 0.3119069	total: 723ms	remaining: 14ms
# 981:	learn: 0.3118473	total: 723ms	remaining: 13.3ms
# 982:	learn: 0.3117858	total: 724ms	remaining: 12.5ms
# 983:	learn: 0.3116635	total: 725ms	remaining: 11.8ms
# 984:	learn: 0.3115930	total: 725ms	remaining: 11ms
# 985:	learn: 0.3115206	total: 726ms	remaining: 10.3ms
# 986:	learn: 0.3114874	total: 726ms	remaining: 9.56ms
# 987:	learn: 0.3114088	total: 727ms	remaining: 8.83ms
# 988:	learn: 0.3113630	total: 727ms	remaining: 8.09ms
# 989:	learn: 0.3112967	total: 728ms	remaining: 7.35ms
# 990:	learn: 0.3112515	total: 729ms	remaining: 6.62ms
# 991:	learn: 0.3111254	total: 729ms	remaining: 5.88ms
# 992:	learn: 0.3110214	total: 730ms	remaining: 5.14ms
# 993:	learn: 0.3109535	total: 730ms	remaining: 4.41ms
# 994:	learn: 0.3109120	total: 731ms	remaining: 3.67ms
# 995:	learn: 0.3108143	total: 731ms	remaining: 2.94ms
# 996:	learn: 0.3107280	total: 732ms	remaining: 2.2ms
# 997:	learn: 0.3106960	total: 732ms	remaining: 1.47ms
# 998:	learn: 0.3105662	total: 733ms	remaining: 733us
# 999:	learn: 0.3104340	total: 734ms	remaining: 0us

# %%
# Podemos generar predicciones para el set de pruebas
y_predict = clf.predict(X_test)

# %%
# ahora vamos a ver qué tal lo ha hecho el modelo Catboost
pred_proba = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, pred_proba[:, 1])
roc_auc = auc(fpr, tpr)

roc_auc
# Out:
# 0.8662714097496707

# %%
# vamos a pintar la curva del ROC / AUC
plt.plot(fpr,tpr)
plt.plot([0, 1], [0, 1], color='r', lw=2, linestyle='--')
plt.xlabel('1 - Exhaustividad (recall) ')
plt.ylabel('Precision')
plt.title('Receiver Operator Characteristic')
plt.show()

# %%
# Otras métrica que podemos sacar son la matriz de confusión del modelo
print(confusion_matrix(y_test, y_predict))
# Out:
# [[100  10]
#  [ 19  50]]

# %%
# Scikit-learn también nos permite calcular fácilmente otras métricas como el F1-score, 
# la precisión del modelo y el recall
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87       110
#            1       0.83      0.72      0.78        69
#
#     accuracy                           0.84       179
#    macro avg       0.84      0.82      0.82       179
# weighted avg       0.84      0.84      0.84       179

# %%
features = X_train
feature_list = X_train.columns

# Guardamos los valores numéricos de la importancia de cada feature
importances = list(clf.feature_importances_)

# Vamos a crear un lista de tuplas con la variable independiente de entrada y su importancia
feature_importances = [(feature, round(importance, 4)) for feature, importance in zip(feature_list, importances)]

# Ordenamos las importancias de las variables para tener las más importantes al principio
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Mostramos las variables y sus importancias
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: Sex                  Importance: 37.2539
# Variable: Age                  Importance: 24.3743
# Variable: Pclass               Importance: 19.8275
# Variable: SibSp                Importance: 8.7224
# Variable: Parch                Importance: 4.1753
# Variable: S                    Importance: 2.5343
# Variable: C                    Importance: 1.8985
# Variable: Q                    Importance: 1.2137

# %%
# También podemos tener una representación gráfica
# creamos una lista con tantas variables como vayamos a pintar
x_values = list(range(len(importances)))

# Creamos un gráfico de barras
plt.bar(x_values, importances, orientation = 'vertical')

# Ponemos los nombres de las variables en el eje x
plt.xticks(x_values, feature_list, rotation='vertical')

# Axis labels and title
# Ponemos los nombres de los ejes y el título
plt.ylabel('Importancia'); plt.xlabel('Variable'); plt.title('Importancias de las variables de entrada');
