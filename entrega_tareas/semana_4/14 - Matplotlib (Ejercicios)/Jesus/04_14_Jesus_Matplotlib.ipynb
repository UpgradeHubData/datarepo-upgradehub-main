# %% [markdown]
# # Ejercicios Matplotlib
#
#
# ## Datos de muestra

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(123) # SEMILLA PARA nÚMEROS ALEATORIOS
x = np.arange(0,100)
y = x*2
z = x**2

# %%
# %matplotlib inline

# %% [markdown]
# ## Ejercicio 1
#
# Reproduce este dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
# Creamos la clase
fig, ax = plt.subplots()
x = np.linspace(0, 100)

# parámetros x, y, color
ax.plot(x, 2*x, 'b')

# Etiquetas de los ejes
ax.set_xlabel('x')
ax.set_ylabel('y')

# Límites de los ejes, """"
ax.set_xlim([0,100])
ax.set_ylim([0,200])

# método con un parámetro que mete los ticks dentro de la gráfica
ax.tick_params( direction= 'in')

# yticks = [0, 50, 100, 150, 200]
ax.set_yticks(list(range(0,250,50)))

# Añadir titulo a la gráfica
ax.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# ## Ejercicio 2
#
# Reproduce el siguiente dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 100, 20)

# Gráfica principal 
ax.plot(x, 2*x, 'r')

# Nombre/Etiqueta de cada eje 
ax.set_xlabel('x')
ax.set_ylabel('y')

# Límites de los ejes, el eje y no hace falta indicarlo xD
ax.set_xlim([0,100])
ax.set_ylim([0,200])

# yticks = [0, 50, 100, 150, 200]
ax.set_yticks(list(range(0,250,50)))

ax.tick_params(direction= 'in')

# inset, segunda gráfica "in" la gráfica que creamos al principio
inset_ax = fig.add_axes([0.28, 0.520, 0.20, 0.20]) # Posición= X, Y, Dimensiones= width, height
inset_ax.plot(x, 2*x, 'r')

# set axis range
inset_ax.set_xlim([0,100])
inset_ax.set_ylim([0,200])

# yticks = [0, 50, 100, 150, 200]
inset_ax.set_yticks(list(range(0,250,50)))
inset_ax.set_xticks(list(range(0,120,20)))

inset_ax.tick_params(direction= 'in')

ax.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# ## Ejercicio 3
#
# Reproduce el siguiente dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 100, 1000)

ax.plot(x, x**2, 'b')

ax.set_xlabel('X')
ax.set_ylabel('Z')

ax.set_xlim([0,100])
ax.set_ylim([0,200])

ax.tick_params(direction = 'in', rotation = 0)

ax.set_yticks(list(range(0,12000,2000)))
ax.set_title('title')

# inset, gráfico "in" 
inset_ax = fig.add_axes([0.28, 0.520, 0.31, 0.31]) # X, Y, width, height

# Titulo
inset_ax.set_title('zoom')

# set axis range
inset_ax.set_xlim([20, 22])
inset_ax.set_ylim([30, 50])

inset_ax.plot(x, x+20, 'b')
inset_ax.set_yticks(list(range(30,55,5)))
inset_ax.set_xticks(list(range(20,23,1)));

# %% [markdown]
# ## Ejercicio 4
#
# Reproduce el siguiente dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
fig, axes = plt.subplots(1, 2, figsize=(6,4))
fig.tight_layout()
x = np.linspace(0,100, 1000)

# default grid appearance
axes[0].plot(x, 2*x, lw=2, linestyle='dashed', color = 'b')
axes[0].set_xlim([0,100])
axes[0].set_ylim([0,200])
axes[0].set_yticks(list(range(0,250,50)))
axes[0].tick_params(direction = 'in', rotation = 0)

# custom grid appearance
axes[1].plot(x, x**2, lw=4, color = 'r')
axes[1].set_xlim([0,100])
axes[1].set_ylim([0,10000])
axes[1].tick_params(direction = 'in', rotation = 0)

# %% [markdown]
# ##Ejercicio 5
#
# Reproduce el siguiente dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
fig, axes = plt.subplots(1, 2, figsize=(9,2))
fig.tight_layout()
x = np.linspace(0,100, 100)

# default grid appearance
axes[0].plot(x, 2*x, lw=6, color = 'b')

# límite de valores de los ejes, no hace falta indicar el intervalo limitante del eje y xD
axes[0].set_xlim([0,100])
axes[0].set_ylim([0,200])

axes[0].set_yticks(list(range(0,250,50)))

axes[0].tick_params(direction = 'in', rotation = 0)

# custom grid appearance
axes[1].plot(x, x**2, lw=3, linestyle= 'dashed', color = 'r')

# Límites
axes[1].set_xlim([0,100])
axes[1].set_ylim([0,10000])

# modificar ticks
axes[1].tick_params(direction = 'in', rotation = 20)

# %% [markdown]
# ## Ejercicio 6
#
# Reproduce el siguiente dibujo a partir del código
#
# ```python
# # Ejes
# ax = plt.axes(projection='3d')
# # Línea
# zline = np.linspace(0, 15, 1000)
# xline = np.sin(zline)
# yline = np.cos(zline)
# # Nube de puntos
# zdata = 15 * np.random.random(100)
# xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
# ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
# ```
#
# ![image.png](data:image/png;base64,...)

# %%
# Ejes
ax = plt.axes(projection='3d')

# Línea
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)

# Nube de puntos
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
 
# dibujar ahora la nube de puntos 
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# añadirle una línea
ax.plot3D(xline, yline, zline, 'grey', lw=1)
